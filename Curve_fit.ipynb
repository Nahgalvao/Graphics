# %% [markdown]
# <a href="https://colab.research.google.com/github/Nahgalvao/Graphics/blob/main/Curve_fit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Curve Fit

# %%
#Importing function
from scipy.optimize import curve_fit
import numpy as np

def exponencial(x,a,b):
  return a*x**b

#Criando valores de x
x = np.linspace(1,10,50)
np.random.seed(123456)

y = exponencial(x, 1, 1.8)

ruido = 2*np.random.normal(size=y.size)
y = y + ruido

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Fit model to experimental points
pars, cov = curve_fit(f=exponencial, xdata=x, ydata=y, p0=[1,1], bounds=(-np.inf,np.inf))

perr = np.sqrt(np.diag(cov))

plt.plot(x,exponencial(x,*pars), linestyle="--", linewidth=2, color="k")
plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from scipy.stats.distributions import gausshyper_gen
#Exemple
from scipy.optimize import curve_fit
import numpy as np

def Gau(x,a,b,c):
  return a*np.exp(-((x-b)**2/(2*c**2)))

x = np.linspace(-10,10,100)
np.random.seed(123456)

y = Gau(x, 8,-1,3)

ruido = 0.5*np.random.normal(size=y.size)
y = y + ruido

pars, cov = curve_fit(f=Gau, xdata=x, ydata=y, p0=[1,1,1], bounds=(-np.inf,np.inf))

perr = np.sqrt(np.diag(cov))

plt.plot(x,Gau(x,*pars), linestyle="--", linewidth=2, color="k")
plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
